# %%
import pandas as pd

# %%
# Dash Data Table input 

spf = pd.read_csv('spf_full')
spf.drop(spf.columns[0], axis=1, inplace=True)
spf_short = spf.drop(columns=['cleaned_list'])
spf_short.sort_values('Product', inplace=True)
spf_short['Product'] = spf_short['Product'].str.replace(' ','', regex=False)
spf_short.rename(columns={'ingredient_list': ' Full Ingredient List'}, inplace=True)
spf_short.head()
# Out:
#    Category Market           Brand                                Product  \
# 49      SPF     US  AustralianGold  AustralianGold-TintedSPF50MediumtoTan
# 47      SPF     US          Aveeno               Aveeno-DailyCalmingSPF19
# 34      SPF     KR            BLab                         BLab-MatchaSPF
# 37      SPF     KR  BeautyofJoseon     BeautyofJoseon-RiceProbioticsSPF50
# 40      SPF     KR          Benton                       Benton-AirfitSPF
#
#                                  Full Ingredient List
# 49  titaniumdioxide(4),zincoxide(4),alumina,butyro...
# 47  avobenzone(3),octinoxate(7.5),octisalate(2),wa...
# 34  water,dibutyladipate,methylpropanediol,alcohol...
# 37  oryzasativa(rice)branwater,glycerin,methylmeth...
# 40  aqua(water),dibutyladipate,propanediol,diethyl...

# %%
price_df = pd.read_csv('Skinlytics - SPF _Price_Qt.csv')
price_df['Product Full Name'] = price_df['Brand']+'-'+price_df['Product ']
price_df.sort_values('Product Full Name',inplace=True )
price_short = price_df[['Product Full Name', 'Qt./unit (ml)', 'Price per unit ', 'Pric/ml']]
price_short.rename(columns={'Product Full Name':'Product', 'Qt./unit (ml)':'Quantity(ml)', 'Price per unit ':'Price(€)', 'Pric/ml':'Price/ml'}, inplace=True)
price_short['Product'] = price_short['Product'].str.replace(' ','', regex=False)
price_short['Price/ml'] = price_short['Price/ml'].str.replace(')','', regex=False)
price_short.head()
# Out:
# /home/rita/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/rita/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/rita/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                   Product  Quantity(ml)  Price(€) Price/ml
# 40  AustralianGold-TintedSPF50MediumtoTan            90     24.00     0.27
# 20               Aveeno-DailyCalmingSPF19           120     20.00     0.17
# 13                         BLab-MatchaSPF            50      5.48     0.11
# 31     BeautyofJoseon-RiceProbioticsSPF50            50     11.00     0.22
# 37                       Benton-AirfitSPF            50     12.77     0.26

# %%
spf_merged = spf_short.merge(price_short, how='left',on='Product')
spf_merged = spf_merged[['Category', 'Market', 'Brand', 'Product', 'Quantity(ml)', 'Price(€)', 'Price/ml', ' Full Ingredient List']]
spf_merged.head()
# Out:
#   Category Market           Brand                                Product  \
# 0      SPF     US  AustralianGold  AustralianGold-TintedSPF50MediumtoTan
# 1      SPF     US          Aveeno               Aveeno-DailyCalmingSPF19
# 2      SPF     KR            BLab                         BLab-MatchaSPF
# 3      SPF     KR  BeautyofJoseon     BeautyofJoseon-RiceProbioticsSPF50
# 4      SPF     KR          Benton                       Benton-AirfitSPF
#
#    Quantity(ml)  Price(€) Price/ml  \
# 0            90     24.00     0.27
# 1           120     20.00     0.17
# 2            50      5.48     0.11
# 3            50     11.00     0.22
# 4            50     12.77     0.26
#
#                                 Full Ingredient List
# 0  titaniumdioxide(4),zincoxide(4),alumina,butyro...
# 1  avobenzone(3),octinoxate(7.5),octisalate(2),wa...
# 2  water,dibutyladipate,methylpropanediol,alcohol...
# 3  oryzasativa(rice)branwater,glycerin,methylmeth...
# 4  aqua(water),dibutyladipate,propanediol,diethyl...
